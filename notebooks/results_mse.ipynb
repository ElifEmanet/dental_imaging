# %% [markdown]
# # t-SNE

# %%
pip install plotly
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

from sklearn.manifold import TSNE

# %% [markdown]
# Get the latent representations of test images and their corresponding classification:

# %%
lat_repr = np.load("../test_results/ae_gauss_40_1/test_lat_repr25-07-2022_14:03:20.npy")
cl_new = np.load("../test_results/ae_gauss_40_1/test_true_class25-07-2022_14:03:20.npy")
view_class = np.load("../test_results/ae_gauss_40_1/test_true_view_class25-07-2022_14:03:20.npy")

# %% [markdown]
# Define the t-SNE plot:

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=1000, random_state=32, metric='euclidean')
lat_r_t = tsne.fit_transform(lat_repr)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
lat_0_0 = lat_r_t[np.where((cl_new == 0) & (view_class == 0))]
lat_0_1 = lat_r_t[np.where((cl_new == 0) & (view_class == 1))]
lat_0_2 = lat_r_t[np.where((cl_new == 0) & (view_class == 2))]
lat_0_3 = lat_r_t[np.where((cl_new == 0) & (view_class == 3))]

# %%
lat_10_0 = lat_r_t[np.where((cl_new == 10) & (view_class == 0))]
lat_10_1 = lat_r_t[np.where((cl_new == 10) & (view_class == 1))]
lat_10_2 = lat_r_t[np.where((cl_new == 10) & (view_class == 2))]
lat_10_3 = lat_r_t[np.where((cl_new == 10) & (view_class == 3))]

# %%
lat_8_0 = lat_r_t[np.where((cl_new == 10) & (view_class == 0))]
lat_8_1 = lat_r_t[np.where((cl_new == 10) & (view_class == 1))]
lat_8_2 = lat_r_t[np.where((cl_new == 10) & (view_class == 2))]
lat_8_3 = lat_r_t[np.where((cl_new == 10) & (view_class == 3))]

# %%
plt.figure(figsize=(6, 4))

# 0
plt.scatter(lat_0_0[:, 0], lat_0_0[:, 1], c ="blue", alpha=0.8, label='normal')
plt.scatter(lat_0_1[:, 0], lat_0_1[:, 1], c ="green", alpha=0.8, label='normal, spine')
plt.scatter(lat_0_2[:, 0], lat_0_2[:, 1], c ="orange", alpha=0.8, label='normal, jaw')
# plt.scatter(lat_0_3[:, 0], lat_0_3[:, 1], c ="cyan", alpha=0.8, label='normal, spine and jaw')
plt.legend(loc='best')
# plt.show()

# %%
# plt.figure(figsize=(8, 6))

# 10
plt.scatter(lat_10_0[:, 0], lat_10_0[:, 1], c ="blue", alpha=0.8, label='normal, artifact')
plt.scatter(lat_10_1[:, 0], lat_10_1[:, 1], c ="green", alpha=0.8, label='normal, artifact, spine')
plt.scatter(lat_10_2[:, 0], lat_10_2[:, 1], c ="orange", alpha=0.8, label='normal, artifact, jaw')
plt.scatter(lat_10_3[:, 0], lat_10_3[:, 1], c ="cyan", alpha=0.8, label='normal, artifact, spine and jaw')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(8, 6))

# 8
plt.scatter(lat_8_0[:, 0], lat_8_0[:, 1], c ="blue", alpha=0.8, label='anomal')
plt.scatter(lat_8_1[:, 0], lat_8_1[:, 1], c ="green", alpha=0.8, label='anomal, spine')
plt.scatter(lat_8_2[:, 0], lat_8_2[:, 1], c ="orange", alpha=0.8, label='anomal, jaw')
plt.scatter(lat_8_3[:, 0], lat_8_3[:, 1], c ="cyan", alpha=0.8, label='anomal, spine and jaw')
plt.legend(loc='best')
plt.show()
